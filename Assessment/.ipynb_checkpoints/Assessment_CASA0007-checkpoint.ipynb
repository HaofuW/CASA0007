# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %% [markdown]
# # Load the data

# %% [markdown]
# ## Life expectancy

# %%
cols_life = ["MSOA11_Name", "MSOA11_Code", "Life_expectancy_male", "Life_expectancy_female"]
df_life = pd.read_excel("https://github.com/HaofuW/CASA0007_Mic/raw/main/Assessment/Data/life_exp_msoa.xlsx", sheet_name = 3, usecols = cols_life)

df_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6789 entries, 0 to 6788
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MSOA11_Name             6789 non-null   object
#  1   MSOA11_Code             6789 non-null   object
#  2   Life_expectancy_male    6789 non-null   float64
#  3   Life_expectancy_female  6783 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 212.3+ KB

# %% [markdown]
# ## Income

# %%
cols_income = ["MSOA_code", "MSOA_name", "Region_name", "Total_annual_income"]
df_income_all = pd.read_excel("https://github.com/HaofuW/CASA0007_Mic/raw/main/Assessment/Data/ons-model-based-income-estimates-msoa.xls", sheet_name = 1, usecols = cols_income)

region = 'London'
df_income = df_income_all[df_income_all.Region_name == region]

df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 983 entries, 4000 to 4982
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MSOA_code            983 non-null    object
#  1   MSOA_name            983 non-null    object
#  2   Region_name          983 non-null    object
#  3   Total_annual_income  983 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 38.4+ KB

# %% [markdown]
# ## House & crime & air & education

# %%
df_hcas = pd.read_csv("https://github.com/HaofuW/CASA0007_Mic/raw/main/Assessment/Data/data.csv")

df_hcas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MSOA_Code         983 non-null    object
#  1   MSOA_Name         984 non-null    object
#  2   house_mean_price  984 non-null    float64
#  3   crime_rate        983 non-null    float64
#  4   PM_index          984 non-null    float64
#  5   education         984 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 46.3+ KB

# %% [markdown]
# # Merge the data

# %%
df_hcasi = pd.merge(df_income, df_hcas,  left_on = 'MSOA_code', right_on = 'MSOA_Code', how = 'inner')
df_hcasi
# Out:
#      MSOA_code           MSOA_name Region_name  Total_annual_income  \
# 0    E02000166          Camden 001      London                55000
# 1    E02000167          Camden 002      London                81600
# 2    E02000168          Camden 003      London                58100
# 3    E02000169          Camden 004      London                75900
# 4    E02000170          Camden 005      London                65400
# ..         ...                 ...         ...                  ...
# 946  E02000918  Waltham Forest 024      London                40900
# 947  E02000919  Waltham Forest 025      London                43700
# 948  E02000920  Waltham Forest 026      London                38700
# 949  E02000921  Waltham Forest 027      London                38400
# 950  E02000922  Waltham Forest 028      London                38400
#
#      MSOA_Code           MSOA_Name                         house_mean_price  \
# 0    E02000166          Camden 001                             841,157.0000
# 1    E02000167          Camden 002                           1,288,115.0000
# 2    E02000168          Camden 003                             658,291.0000
# 3    E02000169          Camden 004                           1,619,090.0000
# 4    E02000170          Camden 005                             647,544.0000
# ..         ...                 ...                                      ...
# 946  E02000918  Waltham Forest 024                             279,661.0000
# 947  E02000919  Waltham Forest 025                             237,888.0000
# 948  E02000920  Waltham Forest 026                             225,167.0000
# 949  E02000921  Waltham Forest 027                             211,028.0000
# 950  E02000922  Waltham Forest 028                             219,229.0000
#
#                                   crime_rate  \
# 0                                    81.0000
# 1                                    78.0000
# 2                                   113.0000
# 3                                    54.0000
# 4                                    55.0000
# ..                                       ...
# 946                                 112.0000
# 947                                  61.0000
# 948                                 129.0000
# 949                                  68.0000
# 950                                  69.0000
#
#                                     PM_index  \
# 0                                    99.0000
# 1                                   101.0000
# 2                                   105.0000
# 3                                   103.0000
# 4                                   102.0000
# ..                                       ...
# 946                                 107.0000
# 947                                 105.0000
# 948                                 102.0000
# 949                                 102.0000
# 950                                  99.0000
#
#                                    education
# 0                                   356.2000
# 1                                   421.0000
# 2                                   466.3000
# 3                                   398.5000
# 4                                   457.4000
# ..                                       ...
# 946                                 384.0000
# 947                                 371.9000
# 948                                 361.4000
# 949                                 371.9000
# 950                                 376.0000
#
# [951 rows x 10 columns]

# %%
df_all = pd.merge(df_hcasi, df_life, left_on = 'MSOA_code', right_on = 'MSOA11_Code', how = 'inner')
df_all
# Out:
#      MSOA_code           MSOA_name Region_name  Total_annual_income  \
# 0    E02000166          Camden 001      London                55000
# 1    E02000167          Camden 002      London                81600
# 2    E02000168          Camden 003      London                58100
# 3    E02000169          Camden 004      London                75900
# 4    E02000170          Camden 005      London                65400
# ..         ...                 ...         ...                  ...
# 945  E02000918  Waltham Forest 024      London                40900
# 946  E02000919  Waltham Forest 025      London                43700
# 947  E02000920  Waltham Forest 026      London                38700
# 948  E02000921  Waltham Forest 027      London                38400
# 949  E02000922  Waltham Forest 028      London                38400
#
#      MSOA_Code           MSOA_Name                         house_mean_price  \
# 0    E02000166          Camden 001                             841,157.0000
# 1    E02000167          Camden 002                           1,288,115.0000
# 2    E02000168          Camden 003                             658,291.0000
# 3    E02000169          Camden 004                           1,619,090.0000
# 4    E02000170          Camden 005                             647,544.0000
# ..         ...                 ...                                      ...
# 945  E02000918  Waltham Forest 024                             279,661.0000
# 946  E02000919  Waltham Forest 025                             237,888.0000
# 947  E02000920  Waltham Forest 026                             225,167.0000
# 948  E02000921  Waltham Forest 027                             211,028.0000
# 949  E02000922  Waltham Forest 028                             219,229.0000
#
#                                   crime_rate  \
# 0                                    81.0000
# 1                                    78.0000
# 2                                   113.0000
# 3                                    54.0000
# 4                                    55.0000
# ..                                       ...
# 945                                 112.0000
# 946                                  61.0000
# 947                                 129.0000
# 948                                  68.0000
# 949                                  69.0000
#
#                                     PM_index  \
# 0                                    99.0000
# 1                                   101.0000
# 2                                   105.0000
# 3                                   103.0000
# 4                                   102.0000
# ..                                       ...
# 945                                 107.0000
# 946                                 105.0000
# 947                                 102.0000
# 948                                 102.0000
# 949                                  99.0000
#
#                                    education         MSOA11_Name MSOA11_Code  \
# 0                                   356.2000          Camden 001   E02000166
# 1                                   421.0000          Camden 002   E02000167
# 2                                   466.3000          Camden 003   E02000168
# 3                                   398.5000          Camden 004   E02000169
# 4                                   457.4000          Camden 005   E02000170
# ..                                       ...                 ...         ...
# 945                                 384.0000  Waltham Forest 024   E02000918
# 946                                 371.9000  Waltham Forest 025   E02000919
# 947                                 361.4000  Waltham Forest 026   E02000920
# 948                                 371.9000  Waltham Forest 027   E02000921
# 949                                 376.0000  Waltham Forest 028   E02000922
#
#                         Life_expectancy_male  \
# 0                                    84.3100
# 1                                    88.8100
# 2                                    81.2800
# 3                                    89.7400
# 4                                    84.4400
# ..                                       ...
# 945                                  82.9700
# 946                                  82.3100
# 947                                  79.3300
# 948                                  77.7400
# 949                                  79.8300
#
#                       Life_expectancy_female
# 0                                    87.4100
# 1                                    92.7700
# 2                                    83.5000
# 3                                    90.5200
# 4                                    90.9400
# ..                                       ...
# 945                                  87.5400
# 946                                  86.0600
# 947                                  84.2400
# 948                                  86.7300
# 949                                  83.6400
#
# [950 rows x 14 columns]

# %%
df_all.drop(df_all[((df_all.crime_rate.isna()))].index, axis=0, inplace=True)
df_all.drop(df_all[((df_all.Total_annual_income.isna()))].index, axis=0, inplace=True)
df_all.drop(df_all[((df_all.house_mean_price.isna()))].index, axis=0, inplace=True)
df_all.drop(df_all[((df_all.PM_index.isna()))].index, axis=0, inplace=True)
df_all.drop(df_all[((df_all.education.isna()))].index, axis=0, inplace=True)
df_all.drop(df_all[((df_all.Life_expectancy_male.isna()))].index, axis=0, inplace=True)
df_all.drop(df_all[((df_all.Life_expectancy_female.isna()))].index, axis=0, inplace=True)
df_all
# Out:
#      MSOA_code           MSOA_name Region_name  Total_annual_income  \
# 0    E02000166          Camden 001      London                55000
# 1    E02000167          Camden 002      London                81600
# 2    E02000168          Camden 003      London                58100
# 3    E02000169          Camden 004      London                75900
# 4    E02000170          Camden 005      London                65400
# ..         ...                 ...         ...                  ...
# 945  E02000918  Waltham Forest 024      London                40900
# 946  E02000919  Waltham Forest 025      London                43700
# 947  E02000920  Waltham Forest 026      London                38700
# 948  E02000921  Waltham Forest 027      London                38400
# 949  E02000922  Waltham Forest 028      London                38400
#
#      MSOA_Code           MSOA_Name                         house_mean_price  \
# 0    E02000166          Camden 001                             841,157.0000
# 1    E02000167          Camden 002                           1,288,115.0000
# 2    E02000168          Camden 003                             658,291.0000
# 3    E02000169          Camden 004                           1,619,090.0000
# 4    E02000170          Camden 005                             647,544.0000
# ..         ...                 ...                                      ...
# 945  E02000918  Waltham Forest 024                             279,661.0000
# 946  E02000919  Waltham Forest 025                             237,888.0000
# 947  E02000920  Waltham Forest 026                             225,167.0000
# 948  E02000921  Waltham Forest 027                             211,028.0000
# 949  E02000922  Waltham Forest 028                             219,229.0000
#
#                                   crime_rate  \
# 0                                    81.0000
# 1                                    78.0000
# 2                                   113.0000
# 3                                    54.0000
# 4                                    55.0000
# ..                                       ...
# 945                                 112.0000
# 946                                  61.0000
# 947                                 129.0000
# 948                                  68.0000
# 949                                  69.0000
#
#                                     PM_index  \
# 0                                    99.0000
# 1                                   101.0000
# 2                                   105.0000
# 3                                   103.0000
# 4                                   102.0000
# ..                                       ...
# 945                                 107.0000
# 946                                 105.0000
# 947                                 102.0000
# 948                                 102.0000
# 949                                  99.0000
#
#                                    education         MSOA11_Name MSOA11_Code  \
# 0                                   356.2000          Camden 001   E02000166
# 1                                   421.0000          Camden 002   E02000167
# 2                                   466.3000          Camden 003   E02000168
# 3                                   398.5000          Camden 004   E02000169
# 4                                   457.4000          Camden 005   E02000170
# ..                                       ...                 ...         ...
# 945                                 384.0000  Waltham Forest 024   E02000918
# 946                                 371.9000  Waltham Forest 025   E02000919
# 947                                 361.4000  Waltham Forest 026   E02000920
# 948                                 371.9000  Waltham Forest 027   E02000921
# 949                                 376.0000  Waltham Forest 028   E02000922
#
#                         Life_expectancy_male  \
# 0                                    84.3100
# 1                                    88.8100
# 2                                    81.2800
# 3                                    89.7400
# 4                                    84.4400
# ..                                       ...
# 945                                  82.9700
# 946                                  82.3100
# 947                                  79.3300
# 948                                  77.7400
# 949                                  79.8300
#
#                       Life_expectancy_female
# 0                                    87.4100
# 1                                    92.7700
# 2                                    83.5000
# 3                                    90.5200
# 4                                    90.9400
# ..                                       ...
# 945                                  87.5400
# 946                                  86.0600
# 947                                  84.2400
# 948                                  86.7300
# 949                                  83.6400
#
# [947 rows x 14 columns]

# %%
df_all.drop(columns=['Region_name','MSOA_Code','MSOA_Name','MSOA11_Name','MSOA11_Code'], inplace=True)
df_all
# Out:
#      MSOA_code           MSOA_name  Total_annual_income  \
# 0    E02000166          Camden 001                55000
# 1    E02000167          Camden 002                81600
# 2    E02000168          Camden 003                58100
# 3    E02000169          Camden 004                75900
# 4    E02000170          Camden 005                65400
# ..         ...                 ...                  ...
# 945  E02000918  Waltham Forest 024                40900
# 946  E02000919  Waltham Forest 025                43700
# 947  E02000920  Waltham Forest 026                38700
# 948  E02000921  Waltham Forest 027                38400
# 949  E02000922  Waltham Forest 028                38400
#
#                             house_mean_price  \
# 0                               841,157.0000
# 1                             1,288,115.0000
# 2                               658,291.0000
# 3                             1,619,090.0000
# 4                               647,544.0000
# ..                                       ...
# 945                             279,661.0000
# 946                             237,888.0000
# 947                             225,167.0000
# 948                             211,028.0000
# 949                             219,229.0000
#
#                                   crime_rate  \
# 0                                    81.0000
# 1                                    78.0000
# 2                                   113.0000
# 3                                    54.0000
# 4                                    55.0000
# ..                                       ...
# 945                                 112.0000
# 946                                  61.0000
# 947                                 129.0000
# 948                                  68.0000
# 949                                  69.0000
#
#                                     PM_index  \
# 0                                    99.0000
# 1                                   101.0000
# 2                                   105.0000
# 3                                   103.0000
# 4                                   102.0000
# ..                                       ...
# 945                                 107.0000
# 946                                 105.0000
# 947                                 102.0000
# 948                                 102.0000
# 949                                  99.0000
#
#                                    education  \
# 0                                   356.2000
# 1                                   421.0000
# 2                                   466.3000
# 3                                   398.5000
# 4                                   457.4000
# ..                                       ...
# 945                                 384.0000
# 946                                 371.9000
# 947                                 361.4000
# 948                                 371.9000
# 949                                 376.0000
#
#                         Life_expectancy_male  \
# 0                                    84.3100
# 1                                    88.8100
# 2                                    81.2800
# 3                                    89.7400
# 4                                    84.4400
# ..                                       ...
# 945                                  82.9700
# 946                                  82.3100
# 947                                  79.3300
# 948                                  77.7400
# 949                                  79.8300
#
#                       Life_expectancy_female
# 0                                    87.4100
# 1                                    92.7700
# 2                                    83.5000
# 3                                    90.5200
# 4                                    90.9400
# ..                                       ...
# 945                                  87.5400
# 946                                  86.0600
# 947                                  84.2400
# 948                                  86.7300
# 949                                  83.6400
#
# [947 rows x 9 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 947 entries, 0 to 949
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MSOA_code               947 non-null    object
#  1   MSOA_name               947 non-null    object
#  2   Total_annual_income     947 non-null    int64
#  3   house_mean_price        947 non-null    float64
#  4   crime_rate              947 non-null    float64
#  5   PM_index                947 non-null    float64
#  6   education               947 non-null    float64
#  7   Life_expectancy_male    947 non-null    float64
#  8   Life_expectancy_female  947 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 74.0+ KB

# %% [markdown]
# # Mapping

# %% [markdown]
# # Correlation Matrix

# %%
# to achieve this result, the two columns 'MSOA' must be dropped.
df_cm = df_all[['Total_annual_income', 'house_mean_price', 'crime_rate', 'PM_index', 'education', 'Life_expectancy_male','Life_expectancy_female']]

plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(10, 10))
plt.matshow(df_cm.corr(), fignum=f.number)
plt.xticks(range(df_cm.shape[1]), df_cm.columns, fontsize=14, rotation=45)
plt.yticks(range(df_cm.shape[1]), df_cm.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
import seaborn as sns

# %%
df_cm.corr()
# Out:
#                                             Total_annual_income  \
# Total_annual_income                                      1.0000
# house_mean_price                                         0.6385
# crime_rate                                              -0.0038
# PM_index                                                 0.0480
# education                                                0.4726
# Life_expectancy_male                                     0.6166
# Life_expectancy_female                                   0.4739
#
#                                                house_mean_price  \
# Total_annual_income                                      0.6385
# house_mean_price                                         1.0000
# crime_rate                                               0.2723
# PM_index                                                 0.4462
# education                                                0.2438
# Life_expectancy_male                                     0.5365
# Life_expectancy_female                                   0.4376
#
#                                                      crime_rate  \
# Total_annual_income                                     -0.0038
# house_mean_price                                         0.2723
# crime_rate                                               1.0000
# PM_index                                                 0.4241
# education                                               -0.0779
# Life_expectancy_male                                    -0.0050
# Life_expectancy_female                                   0.0658
#
#                                                        PM_index  \
# Total_annual_income                                      0.0480
# house_mean_price                                         0.4462
# crime_rate                                               0.4241
# PM_index                                                 1.0000
# education                                               -0.1390
# Life_expectancy_male                                     0.0770
# Life_expectancy_female                                   0.1183
#
#                                                       education  \
# Total_annual_income                                      0.4726
# house_mean_price                                         0.2438
# crime_rate                                              -0.0779
# PM_index                                                -0.1390
# education                                                1.0000
# Life_expectancy_male                                     0.3469
# Life_expectancy_female                                   0.2437
#
#                                            Life_expectancy_male  \
# Total_annual_income                                      0.6166
# house_mean_price                                         0.5365
# crime_rate                                              -0.0050
# PM_index                                                 0.0770
# education                                                0.3469
# Life_expectancy_male                                     1.0000
# Life_expectancy_female                                   0.7026
#
#                                          Life_expectancy_female
# Total_annual_income                                      0.4739
# house_mean_price                                         0.4376
# crime_rate                                               0.0658
# PM_index                                                 0.1183
# education                                                0.2437
# Life_expectancy_male                                     0.7026
# Life_expectancy_female                                   1.0000

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(20, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df_cm.corr(), vmin=-1, vmax=1, annot=True, cmap = 'RdBu')
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# # Basic plotting

# %%
pd.options.display.notebook_repr_html=False 
plt.rcParams['figure.dpi'] = 75 
sns.set_theme(style='darkgrid')

# %%
plt.figure(figsize=(30, 10))
#xticks(np.arange(3), ['Tom', 'Dick', 'Sue'])
x = df_all["MSOA_name"]
y1 = df_all["Life_expectancy_male"]
y2  =df_all["Life_expectancy_female"]
plt.plot(x, y1, lw=1, c='deepskyblue', marker='s', ms=4, label='Male')
plt.plot(x, y2, lw=1, c='salmon', marker='o', label='Female')

plt.ylim(70, 100) 
plt.title('Distributions of Life Expectancy in London MSOA by Gender', fontsize = (25))
plt.ylabel('Life_Expectancy', fontsize = (20))  
plt.xlabel('MSOA_Name', fontsize = (20))
plt.legend(fontsize = (20))
plt.show()

# %%
sns.pairplot(df_cm)
plt.show()

# %% [markdown]
# # Multiple Regression

# %% [markdown]
# ## Male

# %% [markdown]
# ### VIF

# %%
df_all
# Out:
#      MSOA_code           MSOA_name  Total_annual_income  \
# 0    E02000166          Camden 001                55000
# 1    E02000167          Camden 002                81600
# 2    E02000168          Camden 003                58100
# 3    E02000169          Camden 004                75900
# 4    E02000170          Camden 005                65400
# ..         ...                 ...                  ...
# 945  E02000918  Waltham Forest 024                40900
# 946  E02000919  Waltham Forest 025                43700
# 947  E02000920  Waltham Forest 026                38700
# 948  E02000921  Waltham Forest 027                38400
# 949  E02000922  Waltham Forest 028                38400
#
#                             house_mean_price  \
# 0                               841,157.0000
# 1                             1,288,115.0000
# 2                               658,291.0000
# 3                             1,619,090.0000
# 4                               647,544.0000
# ..                                       ...
# 945                             279,661.0000
# 946                             237,888.0000
# 947                             225,167.0000
# 948                             211,028.0000
# 949                             219,229.0000
#
#                                   crime_rate  \
# 0                                    81.0000
# 1                                    78.0000
# 2                                   113.0000
# 3                                    54.0000
# 4                                    55.0000
# ..                                       ...
# 945                                 112.0000
# 946                                  61.0000
# 947                                 129.0000
# 948                                  68.0000
# 949                                  69.0000
#
#                                     PM_index  \
# 0                                    99.0000
# 1                                   101.0000
# 2                                   105.0000
# 3                                   103.0000
# 4                                   102.0000
# ..                                       ...
# 945                                 107.0000
# 946                                 105.0000
# 947                                 102.0000
# 948                                 102.0000
# 949                                  99.0000
#
#                                    education  \
# 0                                   356.2000
# 1                                   421.0000
# 2                                   466.3000
# 3                                   398.5000
# 4                                   457.4000
# ..                                       ...
# 945                                 384.0000
# 946                                 371.9000
# 947                                 361.4000
# 948                                 371.9000
# 949                                 376.0000
#
#                         Life_expectancy_male  \
# 0                                    84.3100
# 1                                    88.8100
# 2                                    81.2800
# 3                                    89.7400
# 4                                    84.4400
# ..                                       ...
# 945                                  82.9700
# 946                                  82.3100
# 947                                  79.3300
# 948                                  77.7400
# 949                                  79.8300
#
#                       Life_expectancy_female
# 0                                    87.4100
# 1                                    92.7700
# 2                                    83.5000
# 3                                    90.5200
# 4                                    90.9400
# ..                                       ...
# 945                                  87.5400
# 946                                  86.0600
# 947                                  84.2400
# 948                                  86.7300
# 949                                  83.6400
#
# [947 rows x 9 columns]

# %%
df_data = df_all.drop(['MSOA_code','MSOA_name'],axis=1)

# %%
def vif(df, col_i):
    """
    df: dataframe
    col_i：the columns that need to be tested
    """
    cols = list(df.columns)
    cols.remove(col_i)
    cols_noti = cols
    formula = col_i + '~' + '+'.join(cols_noti)
    r2 = ols(formula, df).fit().rsquared
    return 1. / (1. - r2)

# %%
from statsmodels.formula.api import ols

for i in df_data.columns:
    print(i, '\t', vif(df=df_data, col_i=i))
# Out:
# Total_annual_income 	 2.5028216944376673
# house_mean_price 	 2.619511447831397
# crime_rate 	 1.2673312698945975
# PM_index 	 1.5933949377014698
# education 	 1.3443396682146007
# Life_expectancy_male 	 2.6076674388661156
# Life_expectancy_female 	 2.011777883093848

# %%
# calculating VIF
# This function is adjusted from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: (default 5) the threshould VIF value. If the VIF of a variable is greater than thresh, it should be removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data. add_constant is a function from statsmodels (see the import above)
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        # If there are multiple variabels with VIF>thresh, only one of them is removed. This is because we want to keep as many variables as possible
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
drop_column_using_vif_
# Out:
# <function __main__.drop_column_using_vif_(df, thresh=5)>

# %%
# using VIF on the new_obesity_VIF_Process_1 dataset
df_all_vif = drop_column_using_vif_(df_data.drop('Life_expectancy_male', axis=1))

print("The columns remaining after VIF selection are:")
print(df_all_vif.columns)
# Out:
# The columns remaining after VIF selection are:
# Index(['Total_annual_income', 'house_mean_price', 'crime_rate', 'PM_index',
#        'education', 'Life_expectancy_female'],
#       dtype='object')

# %% [markdown]
# ### OLS under the logarithm

# %%
model = sm.formula.ols('Life_expectancy_male.apply(np.log) ~ Total_annual_income.apply(np.log) + house_mean_price.apply(np.log) + crime_rate.apply(np.log) + PM_index.apply(np.log) + education.apply(np.log)', df_all).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     OLS Regression Results
# ==============================================================================================
# Dep. Variable:     Life_expectancy_male.apply(np.log)   R-squared:                       0.432
# Model:                                            OLS   Adj. R-squared:                  0.429
# Method:                                 Least Squares   F-statistic:                     143.0
# Date:                                Tue, 18 Jan 2022   Prob (F-statistic):          6.78e-113
# Time:                                        18:54:10   Log-Likelihood:                 2089.1
# No. Observations:                                 947   AIC:                            -4166.
# Df Residuals:                                     941   BIC:                            -4137.
# Df Model:                                           5
# Covariance Type:                            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             3.3581      0.146     22.928      0.000       3.071       3.646
# Total_annual_income.apply(np.log)     0.0601      0.008      7.853      0.000       0.045       0.075
# house_mean_price.apply(np.log)        0.0233      0.003      7.337      0.000       0.017       0.030
# crime_rate.apply(np.log)             -0.0098      0.002     -4.144      0.000      -0.014      -0.005
# PM_index.apply(np.log)               -0.0006      0.028     -0.021      0.983      -0.056       0.054
# education.apply(np.log)               0.0207      0.011      1.940      0.053      -0.000       0.042
# ==============================================================================
# Omnibus:                       32.188   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.114
# Skew:                           0.202   Prob(JB):                     1.20e-14
# Kurtosis:                       4.209   Cond. No.                     3.23e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# erase the PM index
model = sm.formula.ols('Life_expectancy_male.apply(np.log) ~ Total_annual_income.apply(np.log) + house_mean_price.apply(np.log) + crime_rate.apply(np.log) + education.apply(np.log)', df_all).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     OLS Regression Results
# ==============================================================================================
# Dep. Variable:     Life_expectancy_male.apply(np.log)   R-squared:                       0.432
# Model:                                            OLS   Adj. R-squared:                  0.429
# Method:                                 Least Squares   F-statistic:                     179.0
# Date:                                Tue, 18 Jan 2022   Prob (F-statistic):          4.76e-114
# Time:                                        18:54:12   Log-Likelihood:                 2089.1
# No. Observations:                                 947   AIC:                            -4168.
# Df Residuals:                                     942   BIC:                            -4144.
# Df Model:                                           4
# Covariance Type:                            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             3.3554      0.070     48.198      0.000       3.219       3.492
# Total_annual_income.apply(np.log)     0.0602      0.007      8.142      0.000       0.046       0.075
# house_mean_price.apply(np.log)        0.0233      0.003      8.519      0.000       0.018       0.029
# crime_rate.apply(np.log)             -0.0098      0.002     -4.904      0.000      -0.014      -0.006
# education.apply(np.log)               0.0207      0.011      1.947      0.052      -0.000       0.042
# ==============================================================================
# Omnibus:                       32.134   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.991
# Skew:                           0.202   Prob(JB):                     1.27e-14
# Kurtosis:                       4.208   Cond. No.                     1.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
p_value    = model.f_pvalue
R_squared  = model.rsquared
print("R_squared  =", R_squared)
print("p_value    =", p_value)
# Out:
# R_squared  = 0.4318087381877611
# p_value    = 4.75746633924348e-114

# %% [markdown]
# ### Residuals

# %%
plt.scatter(model.fittedvalues, model.resid) # x and y all log
# adding title and labels
plt.xlabel('Fitted Life Expectancy of Male')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Life Expectancy of Male')
plt.show()

# %%
plt.figure()
#ols.fit().model is a method to access to the residual.
model.resid.plot.density()
plt.title('Distribution of Residuals')
plt.show()

# %% [markdown]
# ## Female

# %%
model_f = sm.formula.ols('Life_expectancy_female ~ Total_annual_income + house_mean_price + crime_rate + PM_index + education', df_all).fit()
model_f.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Life_expectancy_female   R-squared:                       0.257
# Model:                                OLS   Adj. R-squared:                  0.253
# Method:                     Least Squares   F-statistic:                     65.05
# Date:                    Tue, 18 Jan 2022   Prob (F-statistic):           2.23e-58
# Time:                            18:54:30   Log-Likelihood:                -2118.4
# No. Observations:                     947   AIC:                             4249.
# Df Residuals:                         941   BIC:                             4278.
# Df Model:                               5
# Covariance Type:                nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              78.4161      2.228     35.199      0.000      74.044      82.788
# Total_annual_income  7.711e-05   1.05e-05      7.357      0.000    5.65e-05    9.77e-05
# house_mean_price     2.119e-06   4.15e-07      5.102      0.000     1.3e-06    2.93e-06
# crime_rate              0.0002      0.001      0.203      0.839      -0.001       0.002
# PM_index                0.0036      0.019      0.187      0.851      -0.034       0.041
# education               0.0027      0.002      1.363      0.173      -0.001       0.007
# ==============================================================================
# Omnibus:                       66.880   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              205.042
# Skew:                           0.308   Prob(JB):                     2.99e-45
# Kurtosis:                       5.195   Cond. No.                     1.46e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
p_value    = model_f.f_pvalue
R_squared  = model_f.rsquared
print("R_squared  =", R_squared)
print("p_value    =", p_value)
# Out:
# R_squared  = 0.2568470945498941
# p_value    = 2.226991722157301e-58

# %%
model_f = sm.formula.ols('Life_expectancy_female.apply(np.log) ~ Total_annual_income.apply(np.log) + house_mean_price.apply(np.log) + crime_rate.apply(np.log) + PM_index.apply(np.log) + education.apply(np.log)', df_all).fit()
model_f.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     Life_expectancy_female.apply(np.log)   R-squared:                       0.265
# Model:                                              OLS   Adj. R-squared:                  0.261
# Method:                                   Least Squares   F-statistic:                     67.99
# Date:                                  Tue, 18 Jan 2022   Prob (F-statistic):           1.02e-60
# Time:                                          18:54:40   Log-Likelihood:                 2095.7
# No. Observations:                                   947   AIC:                            -4179.
# Df Residuals:                                       941   BIC:                            -4150.
# Df Model:                                             5
# Covariance Type:                              nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             3.7205      0.145     25.581      0.000       3.435       4.006
# Total_annual_income.apply(np.log)     0.0360      0.008      4.738      0.000       0.021       0.051
# house_mean_price.apply(np.log)        0.0188      0.003      5.973      0.000       0.013       0.025
# crime_rate.apply(np.log)             -0.0045      0.002     -1.916      0.056      -0.009       0.000
# PM_index.apply(np.log)                0.0102      0.028      0.366      0.715      -0.044       0.065
# education.apply(np.log)               0.0101      0.011      0.954      0.340      -0.011       0.031
# ==============================================================================
# Omnibus:                       66.003   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              242.419
# Skew:                           0.219   Prob(JB):                     2.29e-53
# Kurtosis:                       5.440   Cond. No.                     3.23e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# erase the PM
model_f = sm.formula.ols('Life_expectancy_female.apply(np.log) ~ Total_annual_income.apply(np.log) + house_mean_price.apply(np.log) + crime_rate.apply(np.log) + education.apply(np.log)', df_all).fit()
model_f.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     Life_expectancy_female.apply(np.log)   R-squared:                       0.265
# Model:                                              OLS   Adj. R-squared:                  0.262
# Method:                                   Least Squares   F-statistic:                     85.03
# Date:                                  Tue, 18 Jan 2022   Prob (F-statistic):           1.11e-61
# Time:                                          18:54:43   Log-Likelihood:                 2095.6
# No. Observations:                                   947   AIC:                            -4181.
# Df Residuals:                                       942   BIC:                            -4157.
# Df Model:                                             4
# Covariance Type:                              nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             3.7672      0.069     54.491      0.000       3.632       3.903
# Total_annual_income.apply(np.log)     0.0353      0.007      4.811      0.000       0.021       0.050
# house_mean_price.apply(np.log)        0.0194      0.003      7.161      0.000       0.014       0.025
# crime_rate.apply(np.log)             -0.0040      0.002     -2.032      0.042      -0.008      -0.000
# education.apply(np.log)               0.0099      0.011      0.932      0.351      -0.011       0.031
# ==============================================================================
# Omnibus:                       66.480   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              244.569
# Skew:                           0.222   Prob(JB):                     7.81e-54
# Kurtosis:                       5.450   Cond. No.                     1.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
p_value    = model_f.f_pvalue
R_squared  = model_f.rsquared
print("R_squared  =", R_squared)
print("p_value    =", p_value)
# Out:
# R_squared  = 0.26527842389174117
# p_value    = 1.1066764788525056e-61

# %%
plt.scatter(model_f.fittedvalues, model_f.resid) # x and y all log
# adding title and labels
plt.xlabel('Fitted Life Expectancy of Female')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Life Expectancy of Female')
plt.show()

# %%
plt.figure()
#ols.fit().model is a method to access to the residual.
model_f.resid.plot.density()
plt.title('Distribution of Residuals')
plt.show()

# %% [markdown]
# ### outlier

# %%
df_all_test = df_all.copy()

# %%
# 'Total_annual_income', 'house_mean_price', 'crime_rate', 'PM_index', 'education', 'Life_expectancy'
upper_limit = df_all_test['Life_expectancy_female'].quantile(0.995)
lower_limit = df_all_test['Life_expectancy_female'].quantile(0.005)

# %%
df_all_test=df_all_test[(df_all_test['Life_expectancy_female']<upper_limit)&(df_all_test['Life_expectancy_female']>lower_limit)]

# %%
# erase the PM
model_f = sm.formula.ols('Life_expectancy_female.apply(np.log) ~ Total_annual_income.apply(np.log) + house_mean_price.apply(np.log) + crime_rate.apply(np.log) + education.apply(np.log)', df_all_test).fit()
model_f.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     Life_expectancy_female.apply(np.log)   R-squared:                       0.286
# Model:                                              OLS   Adj. R-squared:                  0.282
# Method:                                   Least Squares   F-statistic:                     93.10
# Date:                                  Tue, 18 Jan 2022   Prob (F-statistic):           1.23e-66
# Time:                                          18:54:56   Log-Likelihood:                 2145.9
# No. Observations:                                   937   AIC:                            -4282.
# Df Residuals:                                       932   BIC:                            -4258.
# Df Model:                                             4
# Covariance Type:                              nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             3.8110      0.065     58.851      0.000       3.684       3.938
# Total_annual_income.apply(np.log)     0.0257      0.007      3.718      0.000       0.012       0.039
# house_mean_price.apply(np.log)        0.0213      0.003      8.338      0.000       0.016       0.026
# crime_rate.apply(np.log)             -0.0062      0.002     -3.229      0.001      -0.010      -0.002
# education.apply(np.log)               0.0173      0.010      1.751      0.080      -0.002       0.037
# ==============================================================================
# Omnibus:                        9.761   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.384
# Skew:                           0.160   Prob(JB):                      0.00337
# Kurtosis:                       3.434   Cond. No.                     1.49e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(model_f.fittedvalues, model_f.resid) # x and y all log
# adding title and labels
plt.xlabel('Fitted Change in Obesity')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of Change in Obesity')
plt.show()

# %%
plt.figure()
#ols.fit().model is a method to access to the residual.
model_f.resid.plot.density()
plt.show()
